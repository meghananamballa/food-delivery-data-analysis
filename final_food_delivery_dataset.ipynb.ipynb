# %% [markdown]
# # Data Analysis Notebook
# This notebook was automatically generated from final_food_delivery_dataset.ipynb.csv
#
# ## Data Overview
# The dataset contains 10001 rows and 12 columns.
#
# ### Column Names:
# - order_id
# - user_id
# - restaurant_id
# - order_date
# - total_amount
# - restaurant_name_x
# - name
# - city
# - membership
# - restaurant_name_y
# - cuisine
# - rating

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# Load the data
df = pd.read_csv('final_food_delivery_dataset.ipynb.csv')
df.head()

# %%
# Basic statistics
df.describe()

# %%
# Check for missing values
df.isnull().sum()

# %%
# Create a correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
